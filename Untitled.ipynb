# %%
# chargement des données
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
main = pd.read_csv("hackhaton_020k_alea_b.csv", encoding= 'cp1252')
# Out:
# C:\Users\maxim\AppData\Local\Temp\ipykernel_20752\784093402.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   main = pd.read_csv("hackhaton_020k_alea_b.csv", encoding= 'cp1252')

# %%
len(set(list(main.EMPLOI_STATUTAIRE)))

# %%
df = pd.read_csv('neg_net_neh.csv', sep = ";", on_bad_lines='skip', encoding='cp1252')
# Out:
# C:\Users\maxim\AppData\Local\Temp\ipykernel_20752\844233406.py:1: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('neg_net_neh.csv', sep = ";", on_bad_lines='skip', encoding='cp1252')

# %%
N4DS = pd.read_csv("N4DS-NET-V01X16.csv", encoding = 'cp1252', on_bad_lines='skip', sep = ";")

# %%
df[df['code_nomenclature_net_neh'] == float('NaN')]['code_NETH_rempl']
# Out:
# Series([], Name: code_NETH_rempl, dtype: object)

# %%
set([a for a in main['EMPLOI_STATUTAIRE'] if (type(a) == float)])
# Out:
# {nan}

# %% [markdown]
# ## Vérifier si tous les codes présents dans N4DS le sont aussi dans neg-net-neh.

# %%
code_N4DS = list(set(N4DS['code']))

# %%
code_df_old = list(np.unique(list(df['code_nomenclature_net_neh'])))

# %%
code_df_new = list(np.unique(list(df['code_NETH_rempl'])))

# %% [markdown]
# Faire des intersects

# %%
every_code_we_know_its_enough = list(set(code_N4DS + code_df_old + code_df_new))

# %%
every_code_we_know_its_enough.sort()

# %%
every_code_we_know_its_enough
# Out:
# ['0010',
#  '0012',
#  '0021',
#  '0031',
#  '0048',
#  '0200',
#  '0211',
#  '0221',
#  '0300',
#  '0310',
#  '0315',
#  '0320',
#  '0325',
#  '0330',
#  '0340',
#  '0342',
#  '0344',
#  '0360',
#  '0420',
#  '0421',
#  '0422',
#  '0423',
#  '0430',
#  '0530',
#  '0540',
#  '0550',
#  '0630',
#  '0640',
#  '0650',
#  '0710',
#  '0720',
#  '0730',
#  '1001',
#  '1002',
#  '1003',
#  '1004',
#  '1011',
#  '1012',
#  '1013',
#  '1014',
#  '1015',
#  '1016',
#  '1017',
#  '1021',
#  '1022',
#  '1023',
#  '1251',
#  '1252',
#  '1253',
#  '1261',
#  '1262',
#  '1263',
#  '1312',
#  '1313',
#  '1314',
#  '1317',
#  '1326',
#  '1327',
#  '1332',
#  '1333',
#  '1353',
#  '1361',
#  '1362',
#  '1363',
#  '1370',
#  '1370.0',
#  '1412',
#  '1423',
#  '1432',
#  '1437',
#  '1451',
#  '1461',
#  '1502',
#  '1504',
#  '1506',
#  '1542',
#  '1561',
#  '1562',
#  '1563',
#  '1568',
#  '1569',
#  '1612',
#  '1622',
#  '1630',
#  '1632',
#  '1801',
#  '1802',
#  '1803',
#  '1804',
#  '1811',
# ...

# %%
maxi = []
for i in range(len(every_code_we_know_its_enough)):
    if len(every_code_we_know_its_enough[i]) > 4 : 
        maxi += [(len(every_code_we_know_its_enough[i]),i)]

# %%
print(maxi)
# Out:
# [(6, 65), (6, 242), (6, 1391)]

# %%
[every_code_we_know_its_enough[i] for i in [65,242,1391]]
# Out:
# ['1370.0', '3166.0', 'S17076']

# %%
'S17076' in code_df_old
# Out:
# True

# %%
and_now_i_do_a_dictionnary = dict([(a,a) for a in every_code_we_know_its_enough])

# %%
len(and_now_i_do_a_dictionnary.keys())
# Out:
# 1753

# %%
def replace(i,data):
    try:
        return data[i]
    except KeyError:
        return float('NaN')

# %%
Liste1 = list(main['EMPLOI_STATUTAIRE'])
Liste2 = [replace(i,and_now_i_do_a_dictionnary) for i in Liste1]
i = 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20752\775233454.py in <module>
#       5     i += 1
#       6     Liste1 = Liste2
# ----> 7     Liste2 = [replace(i,and_now_i_do_a_dictionnary) for i in Liste2]
#       8 i
#
# KeyboardInterrupt:

# %%
Liste1 = list(main['EMPLOI_STATUTAIRE'])
Liste2 = [replace(i,and_now_i_do_a_dictionnary) for i in Liste1]
Liste3 = [replace(i,and_now_i_do_a_dictionnary) for i in Liste2]
diff1  = []
diff2 = []
for i in range(len(Liste1)): 
    if Liste1[i] != Liste2[i] : 
        diff1 += [(i,Liste1[i],Liste2[i])]
    if Liste3[i] != Liste2[i] : 
        diff2 += [(i,Liste2[i],Liste3[i])]

# %%
# Out:
# []

# %%
main['EMPLOI_STATUTAIRE'] = Liste2

# %%
main.to_csv('hackaton_only_known_code.csv')
