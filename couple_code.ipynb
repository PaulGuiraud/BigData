# %% [markdown]
# # Packages

# %%
# chargement des données
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Opening + Reading

# %%
with open('neg_net_neh.csv') as f :
    print(f)
# Out:
# <_io.TextIOWrapper name='neg_net_neh.csv' mode='r' encoding='cp1252'>

# %%
df = pd.read_csv('neg_net_neh.csv', sep = ";", on_bad_lines='skip', encoding='cp1252')
df1 = pd.DataFrame(df)
# Out:
# C:\Users\ester\AppData\Local\Temp\ipykernel_17968\1153115182.py:1: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('neg_net_neh.csv', sep = ";", on_bad_lines='skip', encoding='cp1252')

# %%
#df1[df1['code_NETH_rempl'] == 'TCH1']

# %%
#df1[df1['code_NETH_rempl'] == 'TCH2']

# %% [markdown]
# # Exctracting old and new codes

# %% [markdown]
# ### Old_codesdf['code_nomenclature_net_neh']

# %%
old_code = list(df['code_nomenclature_net_neh'])
old_code = [a[0:4] if type(a) == str else str(np.trunc(a))[0:4] for a in old_code] ## replacing every code by str 
#old_code

# %% [markdown]
# #### Nombre de old codes uniques

# %%
len(np.unique([a for a in old_code]))
# Out:
# 601

# %% [markdown]
# ### New_codes

# %%
new_code = list(df['code_NETH_rempl'])
new_code = [a[0:4] if type(a) == str else str(np.trunc(a))[0:4] for a in new_code]
#new_code

# %% [markdown]
# #### Nombre de old codes uniques

# %%
len(np.unique([a for a in new_code]))
# Out:
# 353

# %% [markdown]
# ### Nombre de NaN dans chaque liste

# %%
print("Nombre de nan dans : old_code :", old_code.count('nan')," where old_code is ", len(old_code), "long")
print("Nombre de nan dans : new_code :", new_code.count('nan')," where new_code is ", len(new_code), "long")
# Out:
# Nombre de nan dans : old_code : 677533  where old_code is  712969 long
# Nombre de nan dans : new_code : 596492  where new_code is  712969 long

# %% [markdown]
# # SANS CODE ETAT

# %% [markdown]
# ### Zip pour avoir chaque couple de code

# %%
list_code_rpl = list(zip(old_code, new_code))
print("Nombre de couple de codes : ", len(list_code_rpl))
#[(a,b) for a,b in list_code_rpl if b == 'TCH1']
# Out:
# Nombre de couple de codes :  712969

# %% [markdown]
# #### Nombre de NaN to NaN

# %%
## Numbers of nan to nan 
nan_to_nan = [[a,b] for a,b in list(list_code_rpl) if (a == 'nan') and (b == 'nan')]
len(nan_to_nan)
# Out:
# 596492

# %% [markdown]
# ## Liste des couples de remplacements de codes (no NaN)

# %%
code_rpl = [(a,b) for a,b in list_code_rpl if (a != b) and (a!= 'nan') and (b != 'nan')]
#code_rpl

# %% [markdown]
# ### Couples uniques

# %%
unique_couples = list(set(code_rpl))
print("Nous avons donc ",len(unique_couples)," différents couples")
# Out:
# Nous avons donc  258  différents couples

# %% [markdown]
# ### Création d'un dictionnaire répertoriant chaque nouveau code et les anciens qui pointent vers lui

# %%
# dict new to old 
unique_new = np.unique([b for a,b in unique_couples])
by_new = [(c,[a for a,b in unique_couples if b == c]) for c in unique_new]

# %% [markdown]
# # NEW RULE :
# ## Il faut prendre les variables 'code_etat' et 'code_grade_NEG' en compte.
# ## Essayer de voir les matchs avec les fichiers de base.

# %%
code_etat = df['code_etat']

# %%
list_code_rpl_etat = list(zip(old_code, new_code, code_etat))
print("Nombre de couple de codes : ", len(list_code_rpl))
#[(a,b) for a,b in list_code_rpl if b == 'TCH1']
# Out:
# Nombre de couple de codes :  712969

# %%
code_rpl_etat = [(a,b,c) for a,b,c in list_code_rpl_etat if (a!= 'nan') and (b != 'nan')]
#code_rpl_etat

# %%
unique_trouples_etat = list(set(code_rpl_etat))
print("Nous avons donc ",len(unique_trouples_etat)," différents trouples")
# Out:
# Nous avons donc  648  différents trouples

# %%
[(a,b,c) for a,b,c in unique_trouples_etat if a == 'TCH2']
# Out:
# [('TCH2', 'TCH1', 2), ('TCH2', 'TCH2', 1)]

# %%
# dict new to old 
unique_new_etat = np.unique([b for a,b,c in unique_trouples_etat])
by_new_etat = [('New code :',new_code,[('Old codes :',old_code,'N. Etat :',nb_etat) for old_code,b,nb_etat in unique_trouples_etat if b == new_code]) for new_code in unique_new_etat]
## vraie liste avec les nouveaux codes états et chaque couple (Ancien code / code état) qui lui sont associés. 
by_new_etat
# Out:
# [('New code :', '0010', [('Old codes :', '0010', 'N. Etat :', 1)]),
#  ('New code :', '0200', [('Old codes :', '0200', 'N. Etat :', 1)]),
#  ('New code :', '0300', [('Old codes :', '0300', 'N. Etat :', 1)]),
#  ('New code :', '0310', [('Old codes :', '0310', 'N. Etat :', 1)]),
#  ('New code :', '0315', [('Old codes :', '0315', 'N. Etat :', 1)]),
#  ('New code :', '0320', [('Old codes :', '0320', 'N. Etat :', 1)]),
#  ('New code :', '0325', [('Old codes :', '0325', 'N. Etat :', 1)]),
#  ('New code :', '0330', [('Old codes :', '0330', 'N. Etat :', 1)]),
#  ('New code :',
#   '0340',
#   [('Old codes :', '0012', 'N. Etat :', 2),
#    ('Old codes :', '0340', 'N. Etat :', 1)]),
#  ('New code :',
#   '0342',
#   [('Old codes :', '0342', 'N. Etat :', 1),
#    ('Old codes :', '0031', 'N. Etat :', 2),
#    ('Old codes :', '0021', 'N. Etat :', 2)]),
#  ('New code :', '0344', [('Old codes :', '0344', 'N. Etat :', 1)]),
#  ('New code :',
#   '0360',
#   [('Old codes :', '0360', 'N. Etat :', 1),
#    ('Old codes :', '0048', 'N. Etat :', 2)]),
#  ('New code :', '0420', [('Old codes :', '0420', 'N. Etat :', 1)]),
#  ('New code :',
#   '0423',
#   [('Old codes :', '0421', 'N. Etat :', 2),
#    ('Old codes :', '0423', 'N. Etat :', 1),
#    ('Old codes :', '0422', 'N. Etat :', 2)]),
#  ('New code :',
#   '0430',
#   [('Old codes :', '0430', 'N. Etat :', 1),
#    ('Old codes :', 'HAA1', 'N. Etat :', 2)]),
#  ('New code :', '0530', [('Old codes :', '0530', 'N. Etat :', 1)]),
#  ('New code :', '0630', [('Old codes :', '0630', 'N. Etat :', 1)]),
#  ('New code :',
#   '0640',
#   [('Old codes :', '0640', 'N. Etat :', 1),
#    ('Old codes :', '0540', 'N. Etat :', 2),
#    ('Old codes :', '0211', 'N. Etat :', 2),
#    ('Old codes :', 'HDC3', 'N. Etat :', 2),
#    ('Old codes :', 'HDB3', 'N. Etat :', 2)]),
#  ('New code :',
#   '0650',
#   [('Old codes :', '0221', 'N. Etat :', 2),
#    ('Old codes :', 'HDC2', 'N. Etat :', 2),
#    ('Old codes :', '0550', 'N. Etat :', 2),
#    ('Old codes :', '0650', 'N. Etat :', 1),
#    ('Old codes :', 'HDC1', 'N. Etat :', 2),
#    ('Old codes :', 'HDB1', 'N. Etat :', 2),
#    ('Old codes :', 'HDB2', 'N. Etat :', 2)]),
#  ('New code :', '0710', [('Old codes :', '0710', 'N. Etat :', 1)]),
#  ('New code :', '0720', [('Old codes :', '0720', 'N. Etat :', 1)]),
#  ('New code :', '0730', [('Old codes :', '0730', 'N. Etat :', 1)]),
#  ('New code :', '1001', [('Old codes :', '1001', 'N. Etat :', 1)]),
#  ('New code :', '1002', [('Old codes :', '1002', 'N. Etat :', 1)]),
#  ('New code :', '1003', [('Old codes :', '1003', 'N. Etat :', 1)]),
#  ('New code :', '1004', [('Old codes :', '1004', 'N. Etat :', 1)]),
#  ('New code :', '1011', [('Old codes :', '1011', 'N. Etat :', 1)]),
#  ('New code :', '1012', [('Old codes :', '1012', 'N. Etat :', 1)]),
#  ('New code :', '1013', [('Old codes :', '1013', 'N. Etat :', 1)]),
#  ('New code :', '1014', [('Old codes :', '1014', 'N. Etat :', 1)]),
#  ('New code :', '1015', [('Old codes :', '1015', 'N. Etat :', 1)]),
#  ('New code :', '1016', [('Old codes :', '1016', 'N. Etat :', 1)]),
#  ('New code :', '1017', [('Old codes :', '1017', 'N. Etat :', 1)]),
#  ('New code :', '1021', [('Old codes :', '1021', 'N. Etat :', 1)]),
#  ('New code :', '1022', [('Old codes :', '1022', 'N. Etat :', 1)]),
#  ('New code :', '1023', [('Old codes :', '1023', 'N. Etat :', 1)]),
#  ('New code :',
#   '1261',
#   [('Old codes :', '1253', 'N. Etat :', 2),
#    ('Old codes :', '1261', 'N. Etat :', 1)]),
#  ('New code :', '1262', [('Old codes :', '1262', 'N. Etat :', 1)]),
#  ('New code :',
#   '1263',
#   [('Old codes :', '1263', 'N. Etat :', 1),
#    ('Old codes :', '1251', 'N. Etat :', 2),
#    ('Old codes :', '1252', 'N. Etat :', 2)]),
#  ('New code :',
#   '1314',
#   [('Old codes :', '1314', 'N. Etat :', 1),
#    ('Old codes :', '1502', 'N. Etat :', 2),
#    ('Old codes :', '1423', 'N. Etat :', 2),
#    ('Old codes :', '1432', 'N. Etat :', 2),
#    ('Old codes :', '1506', 'N. Etat :', 2),
#    ('Old codes :', '1504', 'N. Etat :', 2),
#    ('Old codes :', '1437', 'N. Etat :', 2),
#    ('Old codes :', '1542', 'N. Etat :', 2)]),
#  ('New code :',
#   '1317',
#   [('Old codes :', '1326', 'N. Etat :', 2),
#    ('Old codes :', '1332', 'N. Etat :', 2),
#    ('Old codes :', '1312', 'N. Etat :', 2),
#    ('Old codes :', '1317', 'N. Etat :', 1),
#    ('Old codes :', '1412', 'N. Etat :', 2)]),
#  ('New code :',
#   '1327',
#   [('Old codes :', '1327', 'N. Etat :', 1),
#    ('Old codes :', '1313', 'N. Etat :', 2),
#    ('Old codes :', '1333', 'N. Etat :', 2)]),
#  ('New code :',
#   '1361',
#   [('Old codes :', '1361', 'N. Etat :', 1),
#    ('Old codes :', '1353', 'N. Etat :', 2)]),
#  ('New code :',
#   '1362',
#   [('Old codes :', '1362', 'N. Etat :', 1),
#    ('Old codes :', '1461', 'N. Etat :', 2)]),
#  ('New code :',
#   '1363',
#   [('Old codes :', '1451', 'N. Etat :', 2),
#    ('Old codes :', '1363', 'N. Etat :', 1)]),
#  ('New code :', '1370', [('Old codes :', '1370', 'N. Etat :', 1)]),
#  ('New code :',
#   '1568',
#   [('Old codes :', '1568', 'N. Etat :', 1),
#    ('Old codes :', '1562', 'N. Etat :', 2),
#    ('Old codes :', '1561', 'N. Etat :', 2)]),
#  ('New code :',
#   '1569',
#   [('Old codes :', '1563', 'N. Etat :', 2),
#    ('Old codes :', '1569', 'N. Etat :', 1)]),
#  ('New code :',
#   '1630',
#   [('Old codes :', 'HHA1', 'N. Etat :', 2),
#    ('Old codes :', 'HDD4', 'N. Etat :', 2),
#    ('Old codes :', '1630', 'N. Etat :', 1),
#    ('Old codes :', '1622', 'N. Etat :', 2)]),
#  ('New code :',
#   '1632',
#   [('Old codes :', 'HHA2', 'N. Etat :', 2),
#    ('Old codes :', 'HDD3', 'N. Etat :', 2),
#    ('Old codes :', '1612', 'N. Etat :', 2),
#    ('Old codes :', '1632', 'N. Etat :', 1)]),
#  ('New code :', '1801', [('Old codes :', '1801', 'N. Etat :', 1)]),
#  ('New code :', '1802', [('Old codes :', '1802', 'N. Etat :', 1)]),
#  ('New code :', '1803', [('Old codes :', '1803', 'N. Etat :', 1)]),
#  ('New code :', '1804', [('Old codes :', '1804', 'N. Etat :', 1)]),
#  ('New code :', '1811', [('Old codes :', '1811', 'N. Etat :', 1)]),
#  ('New code :', '1812', [('Old codes :', '1812', 'N. Etat :', 1)]),
#  ('New code :', '1813', [('Old codes :', '1813', 'N. Etat :', 1)]),
#  ('New code :', '1814', [('Old codes :', '1814', 'N. Etat :', 1)]),
#  ('New code :', '1815', [('Old codes :', '1815', 'N. Etat :', 1)]),
#  ('New code :', '1816', [('Old codes :', '1816', 'N. Etat :', 1)]),
#  ('New code :', '1817', [('Old codes :', '1817', 'N. Etat :', 1)]),
#  ('New code :', '1821', [('Old codes :', '1821', 'N. Etat :', 1)]),
#  ('New code :', '1822', [('Old codes :', '1822', 'N. Etat :', 1)]),
#  ('New code :', '1823', [('Old codes :', '1823', 'N. Etat :', 1)]),
#  ('New code :',
#   '2001',
#   [('Old codes :', 'HHB4', 'N. Etat :', 2),
#    ('Old codes :', '2001', 'N. Etat :', 1)]),
#  ('New code :',
#   '2002',
#   [('Old codes :', 'HHD4', 'N. Etat :', 2),
#    ('Old codes :', '2002', 'N. Etat :', 1)]),
#  ('New code :',
#   '2003',
#   [('Old codes :', '2003', 'N. Etat :', 1),
#    ('Old codes :', 'HHC4', 'N. Etat :', 2)]),
#  ('New code :',
#   '2004',
#   [('Old codes :', '2004', 'N. Etat :', 1),
#    ('Old codes :', 'HHE4', 'N. Etat :', 2)]),
#  ('New code :',
#   '2011',
#   [('Old codes :', 'HRE4', 'N. Etat :', 2),
#    ('Old codes :', '2011', 'N. Etat :', 1)]),
#  ('New code :',
#   '2012',
#   [('Old codes :', '2012', 'N. Etat :', 1),
#    ('Old codes :', 'HRF4', 'N. Etat :', 2)]),
#  ('New code :',
#   '2013',
#   [('Old codes :', '2013', 'N. Etat :', 1),
#    ('Old codes :', 'HRG4', 'N. Etat :', 2)]),
#  ('New code :',
#   '2014',
#   [('Old codes :', 'HRD4', 'N. Etat :', 2),
#    ('Old codes :', '2014', 'N. Etat :', 1)]),
#  ('New code :',
#   '2015',
#   [('Old codes :', 'HRA4', 'N. Etat :', 2),
#    ('Old codes :', '2015', 'N. Etat :', 1)]),
#  ('New code :',
#   '2016',
#   [('Old codes :', '2016', 'N. Etat :', 1),
#    ('Old codes :', 'HRB4', 'N. Etat :', 2)]),
#  ('New code :',
#   '2017',
#   [('Old codes :', '2017', 'N. Etat :', 1),
#    ('Old codes :', 'HRC4', 'N. Etat :', 2)]),
#  ('New code :', '2021', [('Old codes :', '2021', 'N. Etat :', 1)]),
#  ('New code :',
#   '2022',
#   [('Old codes :', 'HMA6', 'N. Etat :', 2),
#    ('Old codes :', '2022', 'N. Etat :', 1)]),
#  ('New code :',
#   '2023',
#   [('Old codes :', 'HMB4', 'N. Etat :', 2),
#    ('Old codes :', '2023', 'N. Etat :', 1)]),
#  ('New code :', '2154', [('Old codes :', '2154', 'N. Etat :', 1)]),
#  ('New code :', '2164', [('Old codes :', '2164', 'N. Etat :', 1)]),
#  ('New code :',
#   '2221',
#   [('Old codes :', '2334', 'N. Etat :', 2),
#    ('Old codes :', '2335', 'N. Etat :', 2),
#    ('Old codes :', 'HFA1', 'N. Etat :', 2),
#    ('Old codes :', '2221', 'N. Etat :', 1)]),
#  ('New code :',
#   '2223',
#   [('Old codes :', '2223', 'N. Etat :', 1),
#    ('Old codes :', '2138', 'N. Etat :', 2),
#    ('Old codes :', 'HFA3', 'N. Etat :', 2),
#    ('Old codes :', '2137', 'N. Etat :', 2),
#    ('Old codes :', '2212', 'N. Etat :', 2),
#    ('Old codes :', 'HFA2', 'N. Etat :', 2),
#    ('Old codes :', '2319', 'N. Etat :', 2)]),
#  ('New code :', '2229', [('Old codes :', '2229', 'N. Etat :', 1)]),
#  ('New code :', '2257', [('Old codes :', '2257', 'N. Etat :', 1)]),
#  ('New code :',
#   '2258',
#   [('Old codes :', '2258', 'N. Etat :', 1),
#    ('Old codes :', 'HMC3', 'N. Etat :', 2)]),
#  ('New code :', '2430', [('Old codes :', '2430', 'N. Etat :', 1)]),
#  ('New code :',
#   '2432',
#   [('Old codes :', '2437', 'N. Etat :', 2),
#    ('Old codes :', '2432', 'N. Etat :', 1),
#    ('Old codes :', '2758', 'N. Etat :', 2)]),
#  ('New code :', '2440', [('Old codes :', '2440', 'N. Etat :', 1)]),
#  ('New code :', '2450', [('Old codes :', '2450', 'N. Etat :', 1)]),
#  ('New code :', '2452', [('Old codes :', '2452', 'N. Etat :', 1)]),
#  ('New code :', '2453', [('Old codes :', '2453', 'N. Etat :', 1)]),
#  ('New code :', '2454', [('Old codes :', '2454', 'N. Etat :', 1)]),
#  ('New code :', '2455', [('Old codes :', '2455', 'N. Etat :', 1)]),
#  ('New code :', '2456', [('Old codes :', '2456', 'N. Etat :', 1)]),
#  ('New code :', '2457', [('Old codes :', '2457', 'N. Etat :', 1)]),
#  ('New code :', '2458', [('Old codes :', '2458', 'N. Etat :', 1)]),
#  ('New code :', '2459', [('Old codes :', '2459', 'N. Etat :', 1)]),
#  ('New code :', '2460', [('Old codes :', '2460', 'N. Etat :', 1)]),
#  ('New code :',
#   '2602',
#   [('Old codes :', '2602', 'N. Etat :', 2),
#    ('Old codes :', '2602', 'N. Etat :', 1)]),
#  ('New code :',
#   '2603',
#   [('Old codes :', '2603', 'N. Etat :', 1),
#    ('Old codes :', '2603', 'N. Etat :', 2)]),
#  ('New code :', '2614', [('Old codes :', '2614', 'N. Etat :', 2)]),
#  ('New code :',
#   '2616',
#   [('Old codes :', '2611', 'N. Etat :', 2),
#    ('Old codes :', '2616', 'N. Etat :', 2)]),
#  ('New code :',
#   '2623',
#   [('Old codes :', '2621', 'N. Etat :', 2),
#    ('Old codes :', '2623', 'N. Etat :', 2)]),
#  ('New code :',
#   '2624',
#   [('Old codes :', '2624', 'N. Etat :', 2),
#    ('Old codes :', '2622', 'N. Etat :', 2)]),
#  ('New code :', '2632', [('Old codes :', '2632', 'N. Etat :', 1)]),
#  ('New code :',
#   '2633',
#   [('Old codes :', '2631', 'N. Etat :', 2),
#    ('Old codes :', '2633', 'N. Etat :', 1)]),
#  ('New code :', '2634', [('Old codes :', '2634', 'N. Etat :', 1)]),
#  ('New code :',
#   '2644',
#   [('Old codes :', '2644', 'N. Etat :', 2),
#    ('Old codes :', '2642', 'N. Etat :', 2),
#    ('Old codes :', '2641', 'N. Etat :', 2)]),
#  ('New code :',
#   '2645',
#   [('Old codes :', '2643', 'N. Etat :', 2),
#    ('Old codes :', '2645', 'N. Etat :', 2)]),
#  ('New code :',
#   '2649',
#   [('Old codes :', '2657', 'N. Etat :', 2),
#    ('Old codes :', '2658', 'N. Etat :', 2),
#    ('Old codes :', '2649', 'N. Etat :', 2)]),
#  ('New code :',
#   '2650',
#   [('Old codes :', '2650', 'N. Etat :', 2),
#    ('Old codes :', '2659', 'N. Etat :', 2)]),
#  ('New code :', '2661', [('Old codes :', '2661', 'N. Etat :', 1)]),
#  ('New code :', '2663', [('Old codes :', '2663', 'N. Etat :', 1)]),
#  ('New code :', '2665', [('Old codes :', '2665', 'N. Etat :', 1)]),
#  ('New code :', '2700', [('Old codes :', '2700', 'N. Etat :', 1)]),
#  ('New code :', '2717', [('Old codes :', '2717', 'N. Etat :', 1)]),
#  ('New code :', '2719', [('Old codes :', '2719', 'N. Etat :', 1)]),
#  ('New code :', '2724', [('Old codes :', '2724', 'N. Etat :', 1)]),
#  ('New code :', '2730', [('Old codes :', '2730', 'N. Etat :', 1)]),
#  ('New code :', '2731', [('Old codes :', '2731', 'N. Etat :', 1)]),
#  ('New code :', '2732', [('Old codes :', '2732', 'N. Etat :', 1)]),
#  ('New code :', '2734', [('Old codes :', '2734', 'N. Etat :', 1)]),
#  ('New code :', '2749', [('Old codes :', '2749', 'N. Etat :', 1)]),
#  ('New code :', '2753', [('Old codes :', '2753', 'N. Etat :', 1)]),
#  ('New code :', '2760', [('Old codes :', '2760', 'N. Etat :', 1)]),
#  ('New code :', '2764', [('Old codes :', '2764', 'N. Etat :', 1)]),
#  ('New code :', '2766', [('Old codes :', '2766', 'N. Etat :', 1)]),
#  ('New code :', '2767', [('Old codes :', '2767', 'N. Etat :', 1)]),
#  ('New code :', '2768', [('Old codes :', '2768', 'N. Etat :', 1)]),
#  ('New code :',
#   '2801',
#   [('Old codes :', '2801', 'N. Etat :', 1),
#    ('Old codes :', 'HHB3', 'N. Etat :', 2)]),
#  ('New code :',
#   '2802',
#   [('Old codes :', 'HHD3', 'N. Etat :', 2),
#    ('Old codes :', '2802', 'N. Etat :', 1)]),
#  ('New code :',
#   '2803',
#   [('Old codes :', 'HHC3', 'N. Etat :', 2),
#    ('Old codes :', '2803', 'N. Etat :', 1)]),
#  ('New code :',
#   '2804',
#   [('Old codes :', 'HHE3', 'N. Etat :', 2),
#    ('Old codes :', '2804', 'N. Etat :', 1)]),
#  ('New code :',
#   '2811',
#   [('Old codes :', 'HRE3', 'N. Etat :', 2),
#    ('Old codes :', '2811', 'N. Etat :', 1)]),
#  ('New code :',
#   '2812',
#   [('Old codes :', '2812', 'N. Etat :', 1),
#    ('Old codes :', 'HRF3', 'N. Etat :', 2)]),
#  ('New code :',
#   '2813',
#   [('Old codes :', 'HRG3', 'N. Etat :', 2),
#    ('Old codes :', '2813', 'N. Etat :', 1)]),
#  ('New code :',
#   '2814',
#   [('Old codes :', 'HRD3', 'N. Etat :', 2),
#    ('Old codes :', '2814', 'N. Etat :', 1)]),
#  ('New code :',
#   '2815',
#   [('Old codes :', 'HRA3', 'N. Etat :', 2),
#    ('Old codes :', '2815', 'N. Etat :', 1)]),
#  ('New code :',
#   '2816',
#   [('Old codes :', 'HRB3', 'N. Etat :', 2),
#    ('Old codes :', '2816', 'N. Etat :', 1)]),
#  ('New code :',
#   '2817',
#   [('Old codes :', 'HRC3', 'N. Etat :', 2),
#    ('Old codes :', '2817', 'N. Etat :', 1)]),
#  ('New code :',
#   '2821',
#   [('Old codes :', 'HMC4', 'N. Etat :', 2),
#    ('Old codes :', '2821', 'N. Etat :', 1)]),
#  ('New code :',
#   '2822',
#   [('Old codes :', 'HMA5', 'N. Etat :', 2),
#    ('Old codes :', '2822', 'N. Etat :', 1)]),
#  ('New code :',
#   '2823',
#   [('Old codes :', '2823', 'N. Etat :', 1),
#    ('Old codes :', 'HMB3', 'N. Etat :', 2)]),
#  ('New code :', '2941', [('Old codes :', '2941', 'N. Etat :', 1)]),
#  ('New code :', '2942', [('Old codes :', '2942', 'N. Etat :', 1)]),
#  ('New code :', '2943', [('Old codes :', '2943', 'N. Etat :', 1)]),
#  ('New code :', '2944', [('Old codes :', '2944', 'N. Etat :', 1)]),
#  ('New code :', '2945', [('Old codes :', '2945', 'N. Etat :', 1)]),
#  ('New code :', '2946', [('Old codes :', '2946', 'N. Etat :', 1)]),
#  ('New code :', '2951', [('Old codes :', '2951', 'N. Etat :', 1)]),
#  ('New code :', '2952', [('Old codes :', '2952', 'N. Etat :', 1)]),
#  ('New code :', '2953', [('Old codes :', '2953', 'N. Etat :', 1)]),
#  ('New code :', '2954', [('Old codes :', '2954', 'N. Etat :', 1)]),
#  ('New code :', '2955', [('Old codes :', '2955', 'N. Etat :', 1)]),
#  ('New code :', '2956', [('Old codes :', '2956', 'N. Etat :', 1)]),
#  ('New code :', '2960', [('Old codes :', '2960', 'N. Etat :', 1)]),
#  ('New code :', '2965', [('Old codes :', '2965', 'N. Etat :', 1)]),
#  ('New code :',
#   '3001',
#   [('Old codes :', '3001', 'N. Etat :', 2),
#    ('Old codes :', '3121', 'N. Etat :', 2)]),
#  ('New code :',
#   '3002',
#   [('Old codes :', '3122', 'N. Etat :', 2),
#    ('Old codes :', '3002', 'N. Etat :', 2)]),
#  ('New code :',
#   '3022',
#   [('Old codes :', '3003', 'N. Etat :', 2),
#    ('Old codes :', '3123', 'N. Etat :', 2),
#    ('Old codes :', '3022', 'N. Etat :', 2)]),
#  ('New code :',
#   '3025',
#   [('Old codes :', '3125', 'N. Etat :', 2),
#    ('Old codes :', '3006', 'N. Etat :', 2),
#    ('Old codes :', '3025', 'N. Etat :', 2),
#    ('Old codes :', '3005', 'N. Etat :', 2),
#    ('Old codes :', '3126', 'N. Etat :', 2)]),
#  ('New code :',
#   '3026',
#   [('Old codes :', '3026', 'N. Etat :', 2),
#    ('Old codes :', '3007', 'N. Etat :', 2),
#    ('Old codes :', '3127', 'N. Etat :', 2)]),
#  ('New code :',
#   '3028',
#   [('Old codes :', '3128', 'N. Etat :', 2),
#    ('Old codes :', '3028', 'N. Etat :', 1),
#    ('Old codes :', '3129', 'N. Etat :', 2),
#    ('Old codes :', '3009', 'N. Etat :', 2),
#    ('Old codes :', '3008', 'N. Etat :', 2)]),
#  ('New code :',
#   '3029',
#   [('Old codes :', '3010', 'N. Etat :', 2),
#    ('Old codes :', '3029', 'N. Etat :', 1),
#    ('Old codes :', '3130', 'N. Etat :', 2)]),
#  ('New code :', '3112', [('Old codes :', '3112', 'N. Etat :', 1)]),
#  ('New code :', '3114', [('Old codes :', '3114', 'N. Etat :', 1)]),
#  ('New code :', '3115', [('Old codes :', '3115', 'N. Etat :', 1)]),
#  ('New code :', '3150', [('Old codes :', '3150', 'N. Etat :', 1)]),
#  ('New code :', '3152', [('Old codes :', '3152', 'N. Etat :', 1)]),
#  ('New code :', '3153', [('Old codes :', '3153', 'N. Etat :', 1)]),
#  ('New code :', '3155', [('Old codes :', '3155', 'N. Etat :', 1)]),
#  ('New code :', '3165', [('Old codes :', '3165', 'N. Etat :', 1)]),
#  ('New code :', '3166', [('Old codes :', '3166', 'N. Etat :', 1)]),
#  ('New code :', '3258', [('Old codes :', '3258', 'N. Etat :', 1)]),
#  ('New code :',
#   '3259',
#   [('Old codes :', 'HSD1', 'N. Etat :', 2),
#    ('Old codes :', '3259', 'N. Etat :', 1),
#    ('Old codes :', '3252', 'N. Etat :', 2),
#    ('Old codes :', 'HSD2', 'N. Etat :', 2)]),
#  ('New code :',
#   '4110',
#   [('Old codes :', '4132', 'N. Etat :', 2),
#    ('Old codes :', '4110', 'N. Etat :', 1),
#    ('Old codes :', '4142', 'N. Etat :', 2),
#    ('Old codes :', '4122', 'N. Etat :', 2)]),
#  ('New code :',
#   '4114',
#   [('Old codes :', '4133', 'N. Etat :', 2),
#    ('Old codes :', '4145', 'N. Etat :', 2),
#    ('Old codes :', '4112', 'N. Etat :', 2),
#    ('Old codes :', '4114', 'N. Etat :', 1)]),
#  ('New code :',
#   '4203',
#   [('Old codes :', '4304', 'N. Etat :', 2),
#    ('Old codes :', '4442', 'N. Etat :', 2),
#    ('Old codes :', '4326', 'N. Etat :', 2),
#    ('Old codes :', '4301', 'N. Etat :', 2),
#    ('Old codes :', '4327', 'N. Etat :', 2),
#    ('Old codes :', '4203', 'N. Etat :', 1),
#    ('Old codes :', '4207', 'N. Etat :', 2)]),
#  ('New code :',
#   '4205',
#   [('Old codes :', '4223', 'N. Etat :', 2),
#    ('Old codes :', '4205', 'N. Etat :', 1)]),
#  ('New code :',
#   '4330',
#   [('Old codes :', '4323', 'N. Etat :', 2),
#    ('Old codes :', '4330', 'N. Etat :', 1),
#    ('Old codes :', '4324', 'N. Etat :', 2)]),
#  ('New code :',
#   '4340',
#   [('Old codes :', '4328', 'N. Etat :', 2),
#    ('Old codes :', '4340', 'N. Etat :', 1)]),
#  ('New code :',
#   '4343',
#   [('Old codes :', 'HVK1', 'N. Etat :', 2),
#    ('Old codes :', 'HVL1', 'N. Etat :', 2),
#    ('Old codes :', '4342', 'N. Etat :', 2),
#    ('Old codes :', 'HVL2', 'N. Etat :', 2),
#    ('Old codes :', 'HVK2', 'N. Etat :', 2),
#    ('Old codes :', '4343', 'N. Etat :', 1)]),
#  ('New code :',
#   '4437',
#   [('Old codes :', 'HVG1', 'N. Etat :', 2),
#    ('Old codes :', '4437', 'N. Etat :', 1)]),
#  ('New code :',
#   '5715',
#   [('Old codes :', '5715', 'N. Etat :', 1),
#    ('Old codes :', '5710', 'N. Etat :', 2)]),
#  ('New code :',
#   '5725',
#   [('Old codes :', '5720', 'N. Etat :', 2),
#    ('Old codes :', '5725', 'N. Etat :', 1)]),
#  ('New code :',
#   '5735',
#   [('Old codes :', '5730', 'N. Etat :', 2),
#    ('Old codes :', '5735', 'N. Etat :', 1)]),
#  ('New code :',
#   '5745',
#   [('Old codes :', '5745', 'N. Etat :', 1),
#    ('Old codes :', '5740', 'N. Etat :', 2),
#    ('Old codes :', '5750', 'N. Etat :', 2)]),
#  ('New code :', '5760', [('Old codes :', '5760', 'N. Etat :', 1)]),
#  ('New code :',
#   '5846',
#   [('Old codes :', '4109', 'N. Etat :', 2),
#    ('Old codes :', '5846', 'N. Etat :', 1)]),
#  ('New code :',
#   '5856',
#   [('Old codes :', '4108', 'N. Etat :', 2),
#    ('Old codes :', '5845', 'N. Etat :', 2),
#    ('Old codes :', '5856', 'N. Etat :', 1)]),
#  ('New code :',
#   '5866',
#   [('Old codes :', '5865', 'N. Etat :', 2),
#    ('Old codes :', '4104', 'N. Etat :', 2),
#    ('Old codes :', '5866', 'N. Etat :', 1),
#    ('Old codes :', '5855', 'N. Etat :', 2)]),
#  ('New code :',
#   '5910',
#   [('Old codes :', '5910', 'N. Etat :', 1),
#    ('Old codes :', '5920', 'N. Etat :', 2)]),
#  ('New code :', '5930', [('Old codes :', '5930', 'N. Etat :', 1)]),
#  ('New code :', '6012', [('Old codes :', '6012', 'N. Etat :', 1)]),
#  ('New code :', '6013', [('Old codes :', '6013', 'N. Etat :', 1)]),
#  ('New code :', 'AAG3', [('Old codes :', 'AAG3', 'N. Etat :', 2)]),
#  ('New code :', 'HVH1', [('Old codes :', 'HVH1', 'N. Etat :', 1)]),
#  ('New code :', 'S170', [('Old codes :', 'S170', 'N. Etat :', 1)]),
#  ('New code :',
#   'TAD1',
#   [('Old codes :', 'TAD1', 'N. Etat :', 1),
#    ('Old codes :', 'AAD1', 'N. Etat :', 2)]),
#  ('New code :', 'TAD2', [('Old codes :', 'TAD2', 'N. Etat :', 1)]),
#  ('New code :', 'TAD3', [('Old codes :', 'TAD3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TAJ1',
#   [('Old codes :', 'AAG2', 'N. Etat :', 2),
#    ('Old codes :', 'TAJ1', 'N. Etat :', 2),
#    ('Old codes :', 'TAJ1', 'N. Etat :', 1),
#    ('Old codes :', 'AAG1', 'N. Etat :', 2)]),
#  ('New code :',
#   'TAJ3',
#   [('Old codes :', 'AAJ1', 'N. Etat :', 2),
#    ('Old codes :', 'TAJ2', 'N. Etat :', 2),
#    ('Old codes :', 'TAJ3', 'N. Etat :', 1)]),
#  ('New code :', 'TAJ4', [('Old codes :', 'TAJ4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TAR1',
#   [('Old codes :', 'TAR1', 'N. Etat :', 1),
#    ('Old codes :', 'TAR1', 'N. Etat :', 2)]),
#  ('New code :',
#   'TAR2',
#   [('Old codes :', 'TAR2', 'N. Etat :', 2),
#    ('Old codes :', 'TAR2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TAR3',
#   [('Old codes :', 'TAR3', 'N. Etat :', 1),
#    ('Old codes :', 'TAR3', 'N. Etat :', 2)]),
#  ('New code :', 'TAS1', [('Old codes :', 'TAS1', 'N. Etat :', 1)]),
#  ('New code :', 'TAT1', [('Old codes :', 'TAT1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TAT2',
#   [('Old codes :', 'AAT3', 'N. Etat :', 2),
#    ('Old codes :', 'TAT2', 'N. Etat :', 1),
#    ('Old codes :', 'AAT2', 'N. Etat :', 2)]),
#  ('New code :', 'TAT3', [('Old codes :', 'TAT3', 'N. Etat :', 1)]),
#  ('New code :', 'TAT4', [('Old codes :', 'TAT4', 'N. Etat :', 1)]),
#  ('New code :', 'TAU1', [('Old codes :', 'TAU1', 'N. Etat :', 1)]),
#  ('New code :', 'TAU2', [('Old codes :', 'TAU2', 'N. Etat :', 1)]),
#  ('New code :', 'TCA1', [('Old codes :', 'TCA1', 'N. Etat :', 1)]),
#  ('New code :', 'TCA2', [('Old codes :', 'TCA2', 'N. Etat :', 1)]),
#  ('New code :', 'TCB1', [('Old codes :', 'TCB1', 'N. Etat :', 1)]),
#  ('New code :', 'TCB2', [('Old codes :', 'TCB2', 'N. Etat :', 1)]),
#  ('New code :', 'TCD1', [('Old codes :', 'TCD1', 'N. Etat :', 1)]),
#  ('New code :', 'TCD2', [('Old codes :', 'TCD2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TCG1',
#   [('Old codes :', 'TCG1', 'N. Etat :', 2),
#    ('Old codes :', 'TCG1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TCG2',
#   [('Old codes :', 'TCG2', 'N. Etat :', 1),
#    ('Old codes :', 'TCE1', 'N. Etat :', 2),
#    ('Old codes :', 'TCG2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TCG3',
#   [('Old codes :', 'TCE3', 'N. Etat :', 2),
#    ('Old codes :', 'TCG3', 'N. Etat :', 1),
#    ('Old codes :', 'TCE2', 'N. Etat :', 2),
#    ('Old codes :', 'TCG3', 'N. Etat :', 2)]),
#  ('New code :',
#   'TCH1',
#   [('Old codes :', 'TCH1', 'N. Etat :', 2),
#    ('Old codes :', 'TCH1', 'N. Etat :', 1),
#    ('Old codes :', 'TCH2', 'N. Etat :', 2)]),
#  ('New code :', 'TCH2', [('Old codes :', 'TCH2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TCJ1',
#   [('Old codes :', 'TCJ1', 'N. Etat :', 1),
#    ('Old codes :', 'ACK1', 'N. Etat :', 2),
#    ('Old codes :', 'TCJ1', 'N. Etat :', 2),
#    ('Old codes :', 'ACK2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TCJ3',
#   [('Old codes :', 'TCJ2', 'N. Etat :', 2),
#    ('Old codes :', 'TCJ3', 'N. Etat :', 1),
#    ('Old codes :', 'ACJ1', 'N. Etat :', 2),
#    ('Old codes :', 'ACJ2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TCJ4',
#   [('Old codes :', 'ACJ3', 'N. Etat :', 2),
#    ('Old codes :', 'TCJ4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TCM2',
#   [('Old codes :', 'TCM2', 'N. Etat :', 1),
#    ('Old codes :', 'ACM2', 'N. Etat :', 2),
#    ('Old codes :', 'ACM1', 'N. Etat :', 2)]),
#  ('New code :', 'TCM3', [('Old codes :', 'TCM3', 'N. Etat :', 1)]),
#  ('New code :', 'TCP1', [('Old codes :', 'TCP1', 'N. Etat :', 1)]),
#  ('New code :', 'TCP2', [('Old codes :', 'TCP2', 'N. Etat :', 1)]),
#  ('New code :', 'TCS1', [('Old codes :', 'TCS1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TCS2',
#   [('Old codes :', 'TCS1', 'N. Etat :', 2),
#    ('Old codes :', 'TCS2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TCS3',
#   [('Old codes :', 'TCF1', 'N. Etat :', 2),
#    ('Old codes :', 'TCS3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TEB1',
#   [('Old codes :', 'TEB1', 'N. Etat :', 1),
#    ('Old codes :', 'TEB2', 'N. Etat :', 2),
#    ('Old codes :', 'TEB1', 'N. Etat :', 2)]),
#  ('New code :', 'TEB2', [('Old codes :', 'TEB2', 'N. Etat :', 1)]),
#  ('New code :', 'TEB3', [('Old codes :', 'TEB3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TET1',
#   [('Old codes :', 'TET1', 'N. Etat :', 2),
#    ('Old codes :', 'TEQ1', 'N. Etat :', 2),
#    ('Old codes :', 'TOT1', 'N. Etat :', 2)]),
#  ('New code :',
#   'TET2',
#   [('Old codes :', 'TOT2', 'N. Etat :', 2),
#    ('Old codes :', 'TEQ2', 'N. Etat :', 2),
#    ('Old codes :', 'TET2', 'N. Etat :', 2)]),
#  ('New code :',
#   'THA1',
#   [('Old codes :', 'THA1', 'N. Etat :', 2),
#    ('Old codes :', 'THA1', 'N. Etat :', 1)]),
#  ('New code :',
#   'THO1',
#   [('Old codes :', 'THO1', 'N. Etat :', 2),
#    ('Old codes :', 'THO1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TMA1',
#   [('Old codes :', 'TMA1', 'N. Etat :', 2),
#    ('Old codes :', 'TMA2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TMA2',
#   [('Old codes :', 'TMA2', 'N. Etat :', 2),
#    ('Old codes :', 'TMA3', 'N. Etat :', 2)]),
#  ('New code :',
#   'TMB1',
#   [('Old codes :', 'TMB1', 'N. Etat :', 2),
#    ('Old codes :', 'TMB1', 'N. Etat :', 1)]),
#  ('New code :', 'TMB2', [('Old codes :', 'TMB2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TMD2',
#   [('Old codes :', 'TMD2', 'N. Etat :', 1),
#    ('Old codes :', 'AMS1', 'N. Etat :', 2),
#    ('Old codes :', 'TMD1', 'N. Etat :', 2)]),
#  ('New code :', 'TMD3', [('Old codes :', 'TMD3', 'N. Etat :', 1)]),
#  ('New code :', 'TMH1', [('Old codes :', 'TMH1', 'N. Etat :', 2)]),
#  ('New code :', 'TMH2', [('Old codes :', 'TMH2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TMM1',
#   [('Old codes :', 'TMM1', 'N. Etat :', 2),
#    ('Old codes :', 'TMM1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TMM2',
#   [('Old codes :', 'TMM2', 'N. Etat :', 2),
#    ('Old codes :', 'TMM2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TMP1',
#   [('Old codes :', 'TMP1', 'N. Etat :', 2),
#    ('Old codes :', 'TMP1', 'N. Etat :', 1),
#    ('Old codes :', 'AMG1', 'N. Etat :', 2),
#    ('Old codes :', 'AMG2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TMP3',
#   [('Old codes :', 'AMG3', 'N. Etat :', 2),
#    ('Old codes :', 'TMP2', 'N. Etat :', 2),
#    ('Old codes :', 'TMP3', 'N. Etat :', 1)]),
#  ('New code :', 'TMP4', [('Old codes :', 'TMP4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TNJ1',
#   [('Old codes :', 'ANG2', 'N. Etat :', 2),
#    ('Old codes :', 'TNJ1', 'N. Etat :', 2),
#    ('Old codes :', 'TNJ1', 'N. Etat :', 1),
#    ('Old codes :', 'ANG1', 'N. Etat :', 2)]),
#  ('New code :',
#   'TNJ3',
#   [('Old codes :', 'ANJ2', 'N. Etat :', 2),
#    ('Old codes :', 'ANJ1', 'N. Etat :', 2),
#    ('Old codes :', 'TNJ2', 'N. Etat :', 2),
#    ('Old codes :', 'TNJ3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TNJ4',
#   [('Old codes :', 'ANJ3', 'N. Etat :', 2),
#    ('Old codes :', 'TNJ4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TNN1',
#   [('Old codes :', 'TNN1', 'N. Etat :', 1),
#    ('Old codes :', 'TNN1', 'N. Etat :', 2)]),
#  ('New code :',
#   'TNN2',
#   [('Old codes :', 'TNN2', 'N. Etat :', 1),
#    ('Old codes :', 'TNN2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TNN3',
#   [('Old codes :', 'TNN3', 'N. Etat :', 2),
#    ('Old codes :', 'TNN3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TOA1',
#   [('Old codes :', 'AMN3', 'N. Etat :', 2),
#    ('Old codes :', 'TOA1', 'N. Etat :', 1),
#    ('Old codes :', 'AMT3', 'N. Etat :', 2),
#    ('Old codes :', 'AMQ3', 'N. Etat :', 2)]),
#  ('New code :', 'TOB1', [('Old codes :', 'TOB1', 'N. Etat :', 1)]),
#  ('New code :', 'TOB2', [('Old codes :', 'TOB2', 'N. Etat :', 1)]),
#  ('New code :', 'TOB3', [('Old codes :', 'TOB3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TOC1',
#   [('Old codes :', 'TOC1', 'N. Etat :', 1),
#    ('Old codes :', 'AMP3', 'N. Etat :', 2)]),
#  ('New code :',
#   'TOC2',
#   [('Old codes :', 'TOC2', 'N. Etat :', 1),
#    ('Old codes :', 'AMR1', 'N. Etat :', 2)]),
#  ('New code :', 'TOD1', [('Old codes :', 'TOD1', 'N. Etat :', 1)]),
#  ('New code :', 'TOD2', [('Old codes :', 'TOD2', 'N. Etat :', 1)]),
#  ('New code :', 'TOD3', [('Old codes :', 'TOD3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TOF1',
#   [('Old codes :', 'TOF2', 'N. Etat :', 2),
#    ('Old codes :', 'AMF1', 'N. Etat :', 2),
#    ('Old codes :', 'TOF1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TOF3',
#   [('Old codes :', 'TOF3', 'N. Etat :', 1),
#    ('Old codes :', 'AMF2', 'N. Etat :', 2),
#    ('Old codes :', 'AMF3', 'N. Etat :', 2),
#    ('Old codes :', 'TOF3', 'N. Etat :', 2)]),
#  ('New code :', 'TOG1', [('Old codes :', 'TOG1', 'N. Etat :', 1)]),
#  ('New code :', 'TOG2', [('Old codes :', 'TOG2', 'N. Etat :', 1)]),
#  ('New code :', 'TOG3', [('Old codes :', 'TOG3', 'N. Etat :', 1)]),
#  ('New code :', 'TOH1', [('Old codes :', 'TOH1', 'N. Etat :', 1)]),
#  ('New code :', 'TOH2', [('Old codes :', 'TOH2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TOJ2',
#   [('Old codes :', 'AOJ2', 'N. Etat :', 2),
#    ('Old codes :', 'TOJ1', 'N. Etat :', 2),
#    ('Old codes :', 'TOJ2', 'N. Etat :', 1),
#    ('Old codes :', 'AOJ1', 'N. Etat :', 2),
#    ('Old codes :', 'AOJ3', 'N. Etat :', 2)]),
#  ('New code :', 'TOJ3', [('Old codes :', 'TOJ3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TOK2',
#   [('Old codes :', 'TOK2', 'N. Etat :', 1),
#    ('Old codes :', 'TOK1', 'N. Etat :', 2),
#    ('Old codes :', 'AOK3', 'N. Etat :', 2),
#    ('Old codes :', 'AOK2', 'N. Etat :', 2),
#    ('Old codes :', 'AOK1', 'N. Etat :', 2)]),
#  ('New code :', 'TOK3', [('Old codes :', 'TOK3', 'N. Etat :', 1)]),
#  ('New code :', 'TON1', [('Old codes :', 'TON1', 'N. Etat :', 1)]),
#  ('New code :', 'TON2', [('Old codes :', 'TON2', 'N. Etat :', 1)]),
#  ('New code :', 'TOP1', [('Old codes :', 'TOP1', 'N. Etat :', 1)]),
#  ('New code :', 'TOP2', [('Old codes :', 'TOP2', 'N. Etat :', 1)]),
#  ('New code :', 'TOU1', [('Old codes :', 'TOU1', 'N. Etat :', 1)]),
#  ('New code :', 'TOU2', [('Old codes :', 'TOU2', 'N. Etat :', 1)]),
#  ('New code :', 'TOU3', [('Old codes :', 'TOU3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TPC1',
#   [('Old codes :', 'TPC1', 'N. Etat :', 2),
#    ('Old codes :', 'TPC1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TPC2',
#   [('Old codes :', 'TPC2', 'N. Etat :', 1),
#    ('Old codes :', 'TPC2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TPC3',
#   [('Old codes :', 'TPC3', 'N. Etat :', 2),
#    ('Old codes :', 'TPC3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TPG1',
#   [('Old codes :', 'APG3', 'N. Etat :', 2),
#    ('Old codes :', 'TPG2', 'N. Etat :', 2),
#    ('Old codes :', 'TPG1', 'N. Etat :', 2),
#    ('Old codes :', 'TPG1', 'N. Etat :', 1),
#    ('Old codes :', 'APG4', 'N. Etat :', 2),
#    ('Old codes :', 'APG1', 'N. Etat :', 2),
#    ('Old codes :', 'APG2', 'N. Etat :', 2)]),
#  ('New code :', 'TPG3', [('Old codes :', 'TPG3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TPG4',
#   [('Old codes :', 'TPG4', 'N. Etat :', 2),
#    ('Old codes :', 'TPG4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TPH2',
#   [('Old codes :', 'APH1', 'N. Etat :', 2),
#    ('Old codes :', 'TPH2', 'N. Etat :', 1),
#    ('Old codes :', 'TPH1', 'N. Etat :', 2)]),
#  ('New code :', 'TPH3', [('Old codes :', 'TPH3', 'N. Etat :', 1)]),
#  ('New code :', 'TPU1', [('Old codes :', 'TPU1', 'N. Etat :', 1)]),
#  ('New code :', 'TPU2', [('Old codes :', 'TPU2', 'N. Etat :', 1)]),
#  ('New code :', 'TRB1', [('Old codes :', 'TRB1', 'N. Etat :', 1)]),
#  ('New code :', 'TRB2', [('Old codes :', 'TRB2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRC1',
#   [('Old codes :', 'TRC1', 'N. Etat :', 2),
#    ('Old codes :', 'TRC1', 'N. Etat :', 1)]),
#  ('New code :', 'TRC2', [('Old codes :', 'TRC2', 'N. Etat :', 1)]),
#  ('New code :', 'TRC3', [('Old codes :', 'TRC3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRC4',
#   [('Old codes :', 'TRC4', 'N. Etat :', 2),
#    ('Old codes :', 'TRC4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRD2',
#   [('Old codes :', 'TRD2', 'N. Etat :', 1),
#    ('Old codes :', 'TRD1', 'N. Etat :', 2),
#    ('Old codes :', 'TRD2', 'N. Etat :', 2)]),
#  ('New code :', 'TRD3', [('Old codes :', 'TRD3', 'N. Etat :', 1)]),
#  ('New code :', 'TRD4', [('Old codes :', 'TRD4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRF1',
#   [('Old codes :', 'TRF1', 'N. Etat :', 1),
#    ('Old codes :', 'TRA1', 'N. Etat :', 2)]),
#  ('New code :', 'TRF2', [('Old codes :', 'TRF2', 'N. Etat :', 1)]),
#  ('New code :', 'TRF3', [('Old codes :', 'TRF3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRG1',
#   [('Old codes :', 'TRN1', 'N. Etat :', 2),
#    ('Old codes :', 'TRG1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRG2',
#   [('Old codes :', 'TRG2', 'N. Etat :', 1),
#    ('Old codes :', 'TRN3', 'N. Etat :', 2),
#    ('Old codes :', 'TRN2', 'N. Etat :', 2)]),
#  ('New code :', 'TRG3', [('Old codes :', 'TRG3', 'N. Etat :', 1)]),
#  ('New code :', 'TRH1', [('Old codes :', 'TRH1', 'N. Etat :', 1)]),
#  ('New code :', 'TRH2', [('Old codes :', 'TRH2', 'N. Etat :', 1)]),
#  ('New code :', 'TRH3', [('Old codes :', 'TRH3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRL1',
#   [('Old codes :', 'TRL1', 'N. Etat :', 2),
#    ('Old codes :', 'TRL1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRL2',
#   [('Old codes :', 'TRL2', 'N. Etat :', 2),
#    ('Old codes :', 'TRL2', 'N. Etat :', 1),
#    ('Old codes :', 'ARL3', 'N. Etat :', 2)]),
#  ('New code :', 'TRL3', [('Old codes :', 'TRL3', 'N. Etat :', 1)]),
#  ('New code :', 'TRS1', [('Old codes :', 'TRS1', 'N. Etat :', 1)]),
#  ('New code :', 'TRS2', [('Old codes :', 'TRS2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TRU2',
#   [('Old codes :', 'TRU2', 'N. Etat :', 1),
#    ('Old codes :', 'TRU1', 'N. Etat :', 2)]),
#  ('New code :',
#   'TRU3',
#   [('Old codes :', 'TRU2', 'N. Etat :', 2),
#    ('Old codes :', 'TRU3', 'N. Etat :', 1),
#    ('Old codes :', 'ARS2', 'N. Etat :', 2),
#    ('Old codes :', 'ARS1', 'N. Etat :', 2),
#    ('Old codes :', 'TRS1', 'N. Etat :', 2)]),
#  ('New code :', 'TRU4', [('Old codes :', 'TRU4', 'N. Etat :', 1)]),
#  ('New code :', 'TSC1', [('Old codes :', 'TSC1', 'N. Etat :', 1)]),
#  ('New code :', 'TSC2', [('Old codes :', 'TSC2', 'N. Etat :', 2)]),
#  ('New code :', 'TSC3', [('Old codes :', 'TSC3', 'N. Etat :', 2)]),
#  ('New code :',
#   'TSE1',
#   [('Old codes :', 'TSE1', 'N. Etat :', 2),
#    ('Old codes :', 'TSE1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TSE2',
#   [('Old codes :', 'TSE2', 'N. Etat :', 2),
#    ('Old codes :', 'TSE2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TSE3',
#   [('Old codes :', 'TSE3', 'N. Etat :', 2),
#    ('Old codes :', 'TSE3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TSP2',
#   [('Old codes :', 'TSP1', 'N. Etat :', 2),
#    ('Old codes :', 'TSP2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TSP3',
#   [('Old codes :', 'TSP3', 'N. Etat :', 1),
#    ('Old codes :', 'TSP2', 'N. Etat :', 2)]),
#  ('New code :', 'TSP4', [('Old codes :', 'TSP4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTA2',
#   [('Old codes :', 'TTA1', 'N. Etat :', 2),
#    ('Old codes :', 'TTA2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTA3',
#   [('Old codes :', 'TTA2', 'N. Etat :', 2),
#    ('Old codes :', 'TTA3', 'N. Etat :', 1)]),
#  ('New code :', 'TTA4', [('Old codes :', 'TTA4', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTH1',
#   [('Old codes :', 'TTH1', 'N. Etat :', 2),
#    ('Old codes :', 'TTH1', 'N. Etat :', 1),
#    ('Old codes :', 'ATS1', 'N. Etat :', 2),
#    ('Old codes :', 'ATC1', 'N. Etat :', 2),
#    ('Old codes :', 'ATI1', 'N. Etat :', 2),
#    ('Old codes :', 'ATC2', 'N. Etat :', 2),
#    ('Old codes :', 'ATE1', 'N. Etat :', 2),
#    ('Old codes :', 'ATH1', 'N. Etat :', 2),
#    ('Old codes :', 'ATE2', 'N. Etat :', 2),
#    ('Old codes :', 'AEV1', 'N. Etat :', 2),
#    ('Old codes :', 'AEV2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TTH3',
#   [('Old codes :', 'TTH3', 'N. Etat :', 1),
#    ('Old codes :', 'ATI3', 'N. Etat :', 2),
#    ('Old codes :', 'ATH3', 'N. Etat :', 2),
#    ('Old codes :', 'ATH2', 'N. Etat :', 2),
#    ('Old codes :', 'ATC3', 'N. Etat :', 2),
#    ('Old codes :', 'ATC4', 'N. Etat :', 2),
#    ('Old codes :', 'ATS3', 'N. Etat :', 2),
#    ('Old codes :', 'TTH2', 'N. Etat :', 2),
#    ('Old codes :', 'ATI2', 'N. Etat :', 2),
#    ('Old codes :', 'ATS2', 'N. Etat :', 2)]),
#  ('New code :',
#   'TTH4',
#   [('Old codes :', 'ATI4', 'N. Etat :', 2),
#    ('Old codes :', 'ATS4', 'N. Etat :', 2),
#    ('Old codes :', 'ATH4', 'N. Etat :', 2),
#    ('Old codes :', 'TTH4', 'N. Etat :', 1),
#    ('Old codes :', 'ATC5', 'N. Etat :', 2)]),
#  ('New code :', 'TTM1', [('Old codes :', 'TTM1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTM2',
#   [('Old codes :', 'ATM2', 'N. Etat :', 2),
#    ('Old codes :', 'TTM2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTN1',
#   [('Old codes :', 'TTG3', 'N. Etat :', 2),
#    ('Old codes :', 'TTN1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTN2',
#   [('Old codes :', 'ATG5', 'N. Etat :', 2),
#    ('Old codes :', 'TTN2', 'N. Etat :', 1),
#    ('Old codes :', 'TTG4', 'N. Etat :', 2)]),
#  ('New code :', 'TTN3', [('Old codes :', 'TTN3', 'N. Etat :', 1)]),
#  ('New code :', 'TTP1', [('Old codes :', 'TTP1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTP2',
#   [('Old codes :', 'TTP2', 'N. Etat :', 1),
#    ('Old codes :', 'TTG2', 'N. Etat :', 2)]),
#  ('New code :', 'TTP3', [('Old codes :', 'TTP3', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTT1',
#   [('Old codes :', 'TTO1', 'N. Etat :', 2),
#    ('Old codes :', 'TTT1', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTT2',
#   [('Old codes :', 'TTT1', 'N. Etat :', 2),
#    ('Old codes :', 'TTO2', 'N. Etat :', 2),
#    ('Old codes :', 'TTT2', 'N. Etat :', 1)]),
#  ('New code :',
#   'TTT3',
#   [('Old codes :', 'TTO3', 'N. Etat :', 2),
#    ('Old codes :', 'TTT3', 'N. Etat :', 2),
#    ('Old codes :', 'TTT3', 'N. Etat :', 1),
#    ('Old codes :', 'TTT2', 'N. Etat :', 2)]),
#  ('New code :', 'TTU1', [('Old codes :', 'TTU1', 'N. Etat :', 1)]),
#  ('New code :', 'TTU2', [('Old codes :', 'TTU2', 'N. Etat :', 1)])]

# %%
## Lors du dictionnaire de dictionnaire, si un nouveau code est l'arrivée d'un ancien code sous plusieurs code état, celui apparaitra 1seule fois 
## on veut juste récuperer la liste des anciens codes ne pointant que vers 1 nouveau code. 
by_new_etat_dict = dict([(new_code,{old_code : nb_etat for old_code,b,nb_etat in unique_trouples_etat if b == new_code}) for new_code in unique_new_etat])
by_new_etat_dict
# Out:
# {'0010': {'0010': 1},
#  '0200': {'0200': 1},
#  '0300': {'0300': 1},
#  '0310': {'0310': 1},
#  '0315': {'0315': 1},
#  '0320': {'0320': 1},
#  '0325': {'0325': 1},
#  '0330': {'0330': 1},
#  '0340': {'0012': 2, '0340': 1},
#  '0342': {'0342': 1, '0031': 2, '0021': 2},
#  '0344': {'0344': 1},
#  '0360': {'0360': 1, '0048': 2},
#  '0420': {'0420': 1},
#  '0423': {'0421': 2, '0423': 1, '0422': 2},
#  '0430': {'0430': 1, 'HAA1': 2},
#  '0530': {'0530': 1},
#  '0630': {'0630': 1},
#  '0640': {'0640': 1, '0540': 2, '0211': 2, 'HDC3': 2, 'HDB3': 2},
#  '0650': {'0221': 2,
#   'HDC2': 2,
#   '0550': 2,
#   '0650': 1,
#   'HDC1': 2,
#   'HDB1': 2,
#   'HDB2': 2},
#  '0710': {'0710': 1},
#  '0720': {'0720': 1},
#  '0730': {'0730': 1},
#  '1001': {'1001': 1},
#  '1002': {'1002': 1},
#  '1003': {'1003': 1},
#  '1004': {'1004': 1},
#  '1011': {'1011': 1},
#  '1012': {'1012': 1},
#  '1013': {'1013': 1},
#  '1014': {'1014': 1},
#  '1015': {'1015': 1},
#  '1016': {'1016': 1},
#  '1017': {'1017': 1},
#  '1021': {'1021': 1},
#  '1022': {'1022': 1},
#  '1023': {'1023': 1},
#  '1261': {'1253': 2, '1261': 1},
#  '1262': {'1262': 1},
#  '1263': {'1263': 1, '1251': 2, '1252': 2},
#  '1314': {'1314': 1,
#   '1502': 2,
#   '1423': 2,
#   '1432': 2,
#   '1506': 2,
#   '1504': 2,
#   '1437': 2,
#   '1542': 2},
#  '1317': {'1326': 2, '1332': 2, '1312': 2, '1317': 1, '1412': 2},
#  '1327': {'1327': 1, '1313': 2, '1333': 2},
#  '1361': {'1361': 1, '1353': 2},
#  '1362': {'1362': 1, '1461': 2},
#  '1363': {'1451': 2, '1363': 1},
#  '1370': {'1370': 1},
#  '1568': {'1568': 1, '1562': 2, '1561': 2},
#  '1569': {'1563': 2, '1569': 1},
#  '1630': {'HHA1': 2, 'HDD4': 2, '1630': 1, '1622': 2},
#  '1632': {'HHA2': 2, 'HDD3': 2, '1612': 2, '1632': 1},
#  '1801': {'1801': 1},
#  '1802': {'1802': 1},
#  '1803': {'1803': 1},
#  '1804': {'1804': 1},
#  '1811': {'1811': 1},
#  '1812': {'1812': 1},
#  '1813': {'1813': 1},
#  '1814': {'1814': 1},
#  '1815': {'1815': 1},
#  '1816': {'1816': 1},
#  '1817': {'1817': 1},
#  '1821': {'1821': 1},
#  '1822': {'1822': 1},
#  '1823': {'1823': 1},
#  '2001': {'HHB4': 2, '2001': 1},
#  '2002': {'HHD4': 2, '2002': 1},
#  '2003': {'2003': 1, 'HHC4': 2},
#  '2004': {'2004': 1, 'HHE4': 2},
#  '2011': {'HRE4': 2, '2011': 1},
#  '2012': {'2012': 1, 'HRF4': 2},
#  '2013': {'2013': 1, 'HRG4': 2},
#  '2014': {'HRD4': 2, '2014': 1},
#  '2015': {'HRA4': 2, '2015': 1},
#  '2016': {'2016': 1, 'HRB4': 2},
#  '2017': {'2017': 1, 'HRC4': 2},
#  '2021': {'2021': 1},
#  '2022': {'HMA6': 2, '2022': 1},
#  '2023': {'HMB4': 2, '2023': 1},
#  '2154': {'2154': 1},
#  '2164': {'2164': 1},
#  '2221': {'2334': 2, '2335': 2, 'HFA1': 2, '2221': 1},
#  '2223': {'2223': 1,
#   '2138': 2,
#   'HFA3': 2,
#   '2137': 2,
#   '2212': 2,
#   'HFA2': 2,
#   '2319': 2},
#  '2229': {'2229': 1},
#  '2257': {'2257': 1},
#  '2258': {'2258': 1, 'HMC3': 2},
#  '2430': {'2430': 1},
#  '2432': {'2437': 2, '2432': 1, '2758': 2},
#  '2440': {'2440': 1},
#  '2450': {'2450': 1},
#  '2452': {'2452': 1},
#  '2453': {'2453': 1},
#  '2454': {'2454': 1},
#  '2455': {'2455': 1},
#  '2456': {'2456': 1},
#  '2457': {'2457': 1},
#  '2458': {'2458': 1},
#  '2459': {'2459': 1},
#  '2460': {'2460': 1},
#  '2602': {'2602': 1},
#  '2603': {'2603': 2},
#  '2614': {'2614': 2},
#  '2616': {'2611': 2, '2616': 2},
#  '2623': {'2621': 2, '2623': 2},
#  '2624': {'2624': 2, '2622': 2},
#  '2632': {'2632': 1},
#  '2633': {'2631': 2, '2633': 1},
#  '2634': {'2634': 1},
#  '2644': {'2644': 2, '2642': 2, '2641': 2},
#  '2645': {'2643': 2, '2645': 2},
#  '2649': {'2657': 2, '2658': 2, '2649': 2},
#  '2650': {'2650': 2, '2659': 2},
#  '2661': {'2661': 1},
#  '2663': {'2663': 1},
#  '2665': {'2665': 1},
#  '2700': {'2700': 1},
#  '2717': {'2717': 1},
#  '2719': {'2719': 1},
#  '2724': {'2724': 1},
#  '2730': {'2730': 1},
#  '2731': {'2731': 1},
#  '2732': {'2732': 1},
#  '2734': {'2734': 1},
#  '2749': {'2749': 1},
#  '2753': {'2753': 1},
#  '2760': {'2760': 1},
#  '2764': {'2764': 1},
#  '2766': {'2766': 1},
#  '2767': {'2767': 1},
#  '2768': {'2768': 1},
#  '2801': {'2801': 1, 'HHB3': 2},
#  '2802': {'HHD3': 2, '2802': 1},
#  '2803': {'HHC3': 2, '2803': 1},
#  '2804': {'HHE3': 2, '2804': 1},
#  '2811': {'HRE3': 2, '2811': 1},
#  '2812': {'2812': 1, 'HRF3': 2},
#  '2813': {'HRG3': 2, '2813': 1},
#  '2814': {'HRD3': 2, '2814': 1},
#  '2815': {'HRA3': 2, '2815': 1},
#  '2816': {'HRB3': 2, '2816': 1},
#  '2817': {'HRC3': 2, '2817': 1},
#  '2821': {'HMC4': 2, '2821': 1},
#  '2822': {'HMA5': 2, '2822': 1},
#  '2823': {'2823': 1, 'HMB3': 2},
#  '2941': {'2941': 1},
#  '2942': {'2942': 1},
#  '2943': {'2943': 1},
#  '2944': {'2944': 1},
#  '2945': {'2945': 1},
#  '2946': {'2946': 1},
#  '2951': {'2951': 1},
#  '2952': {'2952': 1},
#  '2953': {'2953': 1},
#  '2954': {'2954': 1},
#  '2955': {'2955': 1},
#  '2956': {'2956': 1},
#  '2960': {'2960': 1},
#  '2965': {'2965': 1},
#  '3001': {'3001': 2, '3121': 2},
#  '3002': {'3122': 2, '3002': 2},
#  '3022': {'3003': 2, '3123': 2, '3022': 2},
#  '3025': {'3125': 2, '3006': 2, '3025': 2, '3005': 2, '3126': 2},
#  '3026': {'3026': 2, '3007': 2, '3127': 2},
#  '3028': {'3128': 2, '3028': 1, '3129': 2, '3009': 2, '3008': 2},
#  '3029': {'3010': 2, '3029': 1, '3130': 2},
#  '3112': {'3112': 1},
#  '3114': {'3114': 1},
#  '3115': {'3115': 1},
#  '3150': {'3150': 1},
#  '3152': {'3152': 1},
#  '3153': {'3153': 1},
#  '3155': {'3155': 1},
#  '3165': {'3165': 1},
#  '3166': {'3166': 1},
#  '3258': {'3258': 1},
#  '3259': {'HSD1': 2, '3259': 1, '3252': 2, 'HSD2': 2},
#  '4110': {'4132': 2, '4110': 1, '4142': 2, '4122': 2},
#  '4114': {'4133': 2, '4145': 2, '4112': 2, '4114': 1},
#  '4203': {'4304': 2,
#   '4442': 2,
#   '4326': 2,
#   '4301': 2,
#   '4327': 2,
#   '4203': 1,
#   '4207': 2},
#  '4205': {'4223': 2, '4205': 1},
#  '4330': {'4323': 2, '4330': 1, '4324': 2},
#  '4340': {'4328': 2, '4340': 1},
#  '4343': {'HVK1': 2, 'HVL1': 2, '4342': 2, 'HVL2': 2, 'HVK2': 2, '4343': 1},
#  '4437': {'HVG1': 2, '4437': 1},
#  '5715': {'5715': 1, '5710': 2},
#  '5725': {'5720': 2, '5725': 1},
#  '5735': {'5730': 2, '5735': 1},
#  '5745': {'5745': 1, '5740': 2, '5750': 2},
#  '5760': {'5760': 1},
#  '5846': {'4109': 2, '5846': 1},
#  '5856': {'4108': 2, '5845': 2, '5856': 1},
#  '5866': {'5865': 2, '4104': 2, '5866': 1, '5855': 2},
#  '5910': {'5910': 1, '5920': 2},
#  '5930': {'5930': 1},
#  '6012': {'6012': 1},
#  '6013': {'6013': 1},
#  'AAG3': {'AAG3': 2},
#  'HVH1': {'HVH1': 1},
#  'S170': {'S170': 1},
#  'TAD1': {'TAD1': 1, 'AAD1': 2},
#  'TAD2': {'TAD2': 1},
#  'TAD3': {'TAD3': 1},
#  'TAJ1': {'AAG2': 2, 'TAJ1': 1, 'AAG1': 2},
#  'TAJ3': {'AAJ1': 2, 'TAJ2': 2, 'TAJ3': 1},
#  'TAJ4': {'TAJ4': 1},
#  'TAR1': {'TAR1': 2},
#  'TAR2': {'TAR2': 1},
#  'TAR3': {'TAR3': 2},
#  'TAS1': {'TAS1': 1},
#  'TAT1': {'TAT1': 1},
#  'TAT2': {'AAT3': 2, 'TAT2': 1, 'AAT2': 2},
#  'TAT3': {'TAT3': 1},
#  'TAT4': {'TAT4': 1},
#  'TAU1': {'TAU1': 1},
#  'TAU2': {'TAU2': 1},
#  'TCA1': {'TCA1': 1},
#  'TCA2': {'TCA2': 1},
#  'TCB1': {'TCB1': 1},
#  'TCB2': {'TCB2': 1},
#  'TCD1': {'TCD1': 1},
#  'TCD2': {'TCD2': 1},
#  'TCG1': {'TCG1': 1},
#  'TCG2': {'TCG2': 2, 'TCE1': 2},
#  'TCG3': {'TCE3': 2, 'TCG3': 2, 'TCE2': 2},
#  'TCH1': {'TCH1': 1, 'TCH2': 2},
#  'TCH2': {'TCH2': 1},
#  'TCJ1': {'TCJ1': 2, 'ACK1': 2, 'ACK2': 2},
#  'TCJ3': {'TCJ2': 2, 'TCJ3': 1, 'ACJ1': 2, 'ACJ2': 2},
#  'TCJ4': {'ACJ3': 2, 'TCJ4': 1},
#  'TCM2': {'TCM2': 1, 'ACM2': 2, 'ACM1': 2},
#  'TCM3': {'TCM3': 1},
#  'TCP1': {'TCP1': 1},
#  'TCP2': {'TCP2': 1},
#  'TCS1': {'TCS1': 1},
#  'TCS2': {'TCS1': 2, 'TCS2': 1},
#  'TCS3': {'TCF1': 2, 'TCS3': 1},
#  'TEB1': {'TEB1': 2, 'TEB2': 2},
#  'TEB2': {'TEB2': 1},
#  'TEB3': {'TEB3': 1},
#  'TET1': {'TET1': 2, 'TEQ1': 2, 'TOT1': 2},
#  'TET2': {'TOT2': 2, 'TEQ2': 2, 'TET2': 2},
#  'THA1': {'THA1': 1},
#  'THO1': {'THO1': 1},
#  'TMA1': {'TMA1': 2, 'TMA2': 2},
#  'TMA2': {'TMA2': 2, 'TMA3': 2},
#  'TMB1': {'TMB1': 1},
#  'TMB2': {'TMB2': 1},
#  'TMD2': {'TMD2': 1, 'AMS1': 2, 'TMD1': 2},
#  'TMD3': {'TMD3': 1},
#  'TMH1': {'TMH1': 2},
#  'TMH2': {'TMH2': 2},
#  'TMM1': {'TMM1': 1},
#  'TMM2': {'TMM2': 1},
#  'TMP1': {'TMP1': 1, 'AMG1': 2, 'AMG2': 2},
#  'TMP3': {'AMG3': 2, 'TMP2': 2, 'TMP3': 1},
#  'TMP4': {'TMP4': 1},
#  'TNJ1': {'ANG2': 2, 'TNJ1': 1, 'ANG1': 2},
#  'TNJ3': {'ANJ2': 2, 'ANJ1': 2, 'TNJ2': 2, 'TNJ3': 1},
#  'TNJ4': {'ANJ3': 2, 'TNJ4': 1},
#  'TNN1': {'TNN1': 2},
#  'TNN2': {'TNN2': 2},
#  'TNN3': {'TNN3': 1},
#  'TOA1': {'AMN3': 2, 'TOA1': 1, 'AMT3': 2, 'AMQ3': 2},
#  'TOB1': {'TOB1': 1},
#  'TOB2': {'TOB2': 1},
#  'TOB3': {'TOB3': 1},
#  'TOC1': {'TOC1': 1, 'AMP3': 2},
#  'TOC2': {'TOC2': 1, 'AMR1': 2},
#  'TOD1': {'TOD1': 1},
#  'TOD2': {'TOD2': 1},
#  'TOD3': {'TOD3': 1},
#  'TOF1': {'TOF2': 2, 'AMF1': 2, 'TOF1': 1},
#  'TOF3': {'TOF3': 2, 'AMF2': 2, 'AMF3': 2},
#  'TOG1': {'TOG1': 1},
#  'TOG2': {'TOG2': 1},
#  'TOG3': {'TOG3': 1},
#  'TOH1': {'TOH1': 1},
#  'TOH2': {'TOH2': 1},
#  'TOJ2': {'AOJ2': 2, 'TOJ1': 2, 'TOJ2': 1, 'AOJ1': 2, 'AOJ3': 2},
#  'TOJ3': {'TOJ3': 1},
#  'TOK2': {'TOK2': 1, 'TOK1': 2, 'AOK3': 2, 'AOK2': 2, 'AOK1': 2},
#  'TOK3': {'TOK3': 1},
#  'TON1': {'TON1': 1},
#  'TON2': {'TON2': 1},
#  'TOP1': {'TOP1': 1},
#  'TOP2': {'TOP2': 1},
#  'TOU1': {'TOU1': 1},
#  'TOU2': {'TOU2': 1},
#  'TOU3': {'TOU3': 1},
#  'TPC1': {'TPC1': 1},
#  'TPC2': {'TPC2': 2},
#  'TPC3': {'TPC3': 1},
#  'TPG1': {'APG3': 2, 'TPG2': 2, 'TPG1': 1, 'APG4': 2, 'APG1': 2, 'APG2': 2},
#  'TPG3': {'TPG3': 1},
#  'TPG4': {'TPG4': 1},
#  'TPH2': {'APH1': 2, 'TPH2': 1, 'TPH1': 2},
#  'TPH3': {'TPH3': 1},
#  'TPU1': {'TPU1': 1},
#  'TPU2': {'TPU2': 1},
#  'TRB1': {'TRB1': 1},
#  'TRB2': {'TRB2': 1},
#  'TRC1': {'TRC1': 1},
#  'TRC2': {'TRC2': 1},
#  'TRC3': {'TRC3': 1},
#  'TRC4': {'TRC4': 1},
#  'TRD2': {'TRD2': 2, 'TRD1': 2},
#  'TRD3': {'TRD3': 1},
#  'TRD4': {'TRD4': 1},
#  'TRF1': {'TRF1': 1, 'TRA1': 2},
#  'TRF2': {'TRF2': 1},
#  'TRF3': {'TRF3': 1},
#  'TRG1': {'TRN1': 2, 'TRG1': 1},
#  'TRG2': {'TRG2': 1, 'TRN3': 2, 'TRN2': 2},
#  'TRG3': {'TRG3': 1},
#  'TRH1': {'TRH1': 1},
#  'TRH2': {'TRH2': 1},
#  'TRH3': {'TRH3': 1},
#  'TRL1': {'TRL1': 1},
#  'TRL2': {'TRL2': 1, 'ARL3': 2},
#  'TRL3': {'TRL3': 1},
#  'TRS1': {'TRS1': 1},
#  'TRS2': {'TRS2': 1},
#  'TRU2': {'TRU2': 1, 'TRU1': 2},
#  'TRU3': {'TRU2': 2, 'TRU3': 1, 'ARS2': 2, 'ARS1': 2, 'TRS1': 2},
#  'TRU4': {'TRU4': 1},
#  'TSC1': {'TSC1': 1},
#  'TSC2': {'TSC2': 2},
#  'TSC3': {'TSC3': 2},
#  'TSE1': {'TSE1': 1},
#  'TSE2': {'TSE2': 1},
#  'TSE3': {'TSE3': 1},
#  'TSP2': {'TSP1': 2, 'TSP2': 1},
#  'TSP3': {'TSP3': 1, 'TSP2': 2},
#  'TSP4': {'TSP4': 1},
#  'TTA2': {'TTA1': 2, 'TTA2': 1},
#  'TTA3': {'TTA2': 2, 'TTA3': 1},
#  'TTA4': {'TTA4': 1},
#  'TTH1': {'TTH1': 1,
#   'ATS1': 2,
#   'ATC1': 2,
#   'ATI1': 2,
#   'ATC2': 2,
#   'ATE1': 2,
#   'ATH1': 2,
#   'ATE2': 2,
#   'AEV1': 2,
#   'AEV2': 2},
#  'TTH3': {'TTH3': 1,
#   'ATI3': 2,
#   'ATH3': 2,
#   'ATH2': 2,
#   'ATC3': 2,
#   'ATC4': 2,
#   'ATS3': 2,
#   'TTH2': 2,
#   'ATI2': 2,
#   'ATS2': 2},
#  'TTH4': {'ATI4': 2, 'ATS4': 2, 'ATH4': 2, 'TTH4': 1, 'ATC5': 2},
#  'TTM1': {'TTM1': 1},
#  'TTM2': {'ATM2': 2, 'TTM2': 1},
#  'TTN1': {'TTG3': 2, 'TTN1': 1},
#  'TTN2': {'ATG5': 2, 'TTN2': 1, 'TTG4': 2},
#  'TTN3': {'TTN3': 1},
#  'TTP1': {'TTP1': 1},
#  'TTP2': {'TTP2': 1, 'TTG2': 2},
#  'TTP3': {'TTP3': 1},
#  'TTT1': {'TTO1': 2, 'TTT1': 1},
#  'TTT2': {'TTT1': 2, 'TTO2': 2, 'TTT2': 1},
#  'TTT3': {'TTO3': 2, 'TTT3': 1, 'TTT2': 2},
#  'TTU1': {'TTU1': 1},
#  'TTU2': {'TTU2': 1}}

# %%
unique_old_etat = np.unique([a for a,b,c in unique_trouples_etat])

# %%
dict_old_code_remplacable_c_to_v = {}
dict_old_code_remplacable_v_to_c = {True : [] ,False : []}
for old_code in unique_old_etat :
    result = 0 
    for new_code in by_new_etat_dict.keys():
        if old_code in by_new_etat_dict[new_code]:
            result += 1
    dict_old_code_remplacable_v_to_c[result == 1].append(old_code)
    dict_old_code_remplacable[old_code] = (result == 1)

# %%
len(dict_old_code_remplacable_v_to_c[True])
# Out:
# 590
