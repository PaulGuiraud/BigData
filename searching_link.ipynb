# %% [markdown]
# Regarder tous les fihier et chercher des liens dans les fichiers sachant que :
# - les partie importantes dans les codes de remplacements sont : Old code, New code et Code d'état lié à une autre variable
# - Lien potentiel entre Code d'état et Indice Brut

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Hackaton  : Fichier Individus

# %%
main = pd.read_csv("hackhaton_020k_alea_b.csv", encoding= 'cp1252')
# Out:
# C:\Users\ester\AppData\Local\Temp\ipykernel_20152\784093402.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   main = pd.read_csv("hackhaton_020k_alea_b.csv", encoding= 'cp1252')

# %%
st = f"Dans la colonne ETAT, nous trouvons donc :"
for i in np.unique(main['ETAT']): 
    st = st + f" {list(main['ETAT']).count(i)} valeurs {i} ;"
st = st [:-1]
st
# Out:
# 'Dans la colonne ETAT, nous trouvons donc : 976819 valeurs 1 ; 6 valeurs 4 ; 71750 valeurs 5 '

# %% [markdown]
# ## Codes

# %%
codes = pd.read_csv("neg_net_neh.csv", encoding = 'cp1252', sep = ";", on_bad_lines='skip')
# Out:
# C:\Users\ester\AppData\Local\Temp\ipykernel_20152\577997651.py:1: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   codes = pd.read_csv("neg_net_neh.csv", encoding = 'cp1252', sep = ";", on_bad_lines='skip')

# %%
codes
# Out:
#        code_grade_NEG           libelle_grade_neg code_nomenclature_net_neh  \
# 0                0001  ADMINISTRATEUR HORS CLASSE                      TAD2
# 1                0001  ADMINISTRATEUR HORS CLASSE                      TAD2
# 2                0001  ADMINISTRATEUR HORS CLASSE                      TAD2
# 3                0001  ADMINISTRATEUR HORS CLASSE                      TAD2
# 4                0001  ADMINISTRATEUR HORS CLASSE                      TAD2
# ...               ...                         ...                       ...
# 712964         S17082         PROFESSEUR DE PIANO                       NaN
# 712965         S17082         PROFESSEUR DE PIANO                       NaN
# 712966         S17082         PROFESSEUR DE PIANO                       NaN
# 712967         S17082         PROFESSEUR DE PIANO                       NaN
# 712968         S17082         PROFESSEUR DE PIANO                       NaN
#
# ...

# %% [markdown]
# ## Caracteristiques

# %%
carac = pd.read_csv("1 - neg_caracteristique.csv", encoding = "cp1252",on_bad_lines='skip', sep = ";")

# %%
carac
# Out:
#       code_grade_NEG                                  libelle_grade_neg  \
# 0               0001                         ADMINISTRATEUR HORS CLASSE
# 1               0002                  ADMINISTRATEUR DE PREMIERE CLASSE
# 2               0003                  ADMINISTRATEUR DE DEUXIEME CLASSE
# 3               0004                 DIRECTEUR DE CLASSE EXCEPTIONNELLE
# 4               0005            DIRECTEUR TERRITORIAL DE CLASSE NORMALE
# ...              ...                                                ...
# 17252         S17074                              GRAPHISTE-MAQUETTISTE
# 17253         S17076                         DIRECTEUR ECOLE DE MUSIQUE
# 17254         S17079  SECRETAIRE GENERAL DU TRIBUNAL DE COMMERCE 1ER...
# 17255         S17081  SECRETAIRE GENERAL DU TRIBUNAL DE COMMERCE 2EM...
# 17256         S17082                                PROFESSEUR DE PIANO
#
#       code_nomenclature_net_neh             libelle_NET_NEH  \
# ...

# %% [markdown]
# ## N4DS (pour l'instant, ne sert à rien.)

# %%
N4DS = pd.read_csv("N4DS-NET-V01X16.csv", encoding = 'cp1252', on_bad_lines='skip', sep = ";")

# %%
N4DS
# Out:
#       code                                            libellé  01/07/2021
# 0     BAD1                          Non-TIT. / Administrateur         NaN
# 1     BAD2              Non-TIT. / Administrateur hors classe         NaN
# 2     BAD3                  Non-TIT. / Administrateur général         NaN
# 3     BAJ1                   Non-TIT. / Adjoint administratif         NaN
# 4     BAJ3  Non-TIT. / Adjoint administratif principal de ...         NaN
# ...    ...                                                ...         ...
# 1295  YYX1                                  AUTRES / Apprenti         NaN
# 1296  YYX2                                       AUTRES / Elu         NaN
# 1297  YYX3  AUTRES / Agent en congé de fin d'activité, ret...         NaN
# 1298  YYX4  AUTRES / Agent exerçant des activités accessoi...         NaN
# 1299  YYX9  AUTRES / Autre (non classable dans les rubriqu...         NaN
#
# [1300 rows x 3 columns]

# %% [markdown]
# ## Old Codes and Etat

# %%
## I wrote this to find links beetween old code, etat number & new code
old_code_etat = pd.read_csv('old_code_and_etat.csv')
# Out:
# C:\Users\ester\AppData\Local\Temp\ipykernel_20152\2877481070.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   old_code_etat = pd.read_csv('old_code_and_etat.csv')

# %%
old_code_etat
# Out:
#         Unnamed: 0 code_nomenclature_net_neh  code_etat
# 0                0                      TAD2          1
# 1                1                      TAD2          1
# 2                2                      TAD2          1
# 3                3                      TAD2          1
# 4                4                      TAD2          1
# ...            ...                       ...        ...
# 712964      712964                       NaN          1
# 712965      712965                       NaN          1
# 712966      712966                       NaN          1
# 712967      712967                       NaN          1
# 712968      712968                       NaN          1
#
# [712969 rows x 3 columns]

# %% [markdown]
# ## Nomenclature des emplois hospitaliers

# %%
NEH_2022 = pd.read_excel('NEH_2022_nehpnm20221006.xls')

# %%
NEH_2022
# Out:
#      DatVersion Date modification NEH  Code SAE Niv1  \
# 0          2022            2010-11-12           1000
# 1          2022            2010-11-12           1000
# 2          2022            2010-11-12           1000
# 3          2022            2010-11-12           1000
# 4          2022            2010-11-12           1000
# ..          ...                   ...            ...
# 528        2022            2010-11-12           3000
# 529        2022            2010-11-12           5000
# 530        2022            2016-10-27           9999
# 531        2022            2017-09-01           5000
# 532        2022            2017-09-01           5000
#
#                       Libellé de la filière (SAE Niv1) Code Corps  \
# 0    Personnel de direction et personnel administratif       0001
# 1    Personnel de direction et personnel administratif       0001
# 2    Personnel de direction et personnel administratif       0001
# ...
